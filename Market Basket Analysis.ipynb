# %%
# !pip install mlxtend

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_csv(r"C:\Users\pc\Downloads\Groceries_dataset.csv")

# %%
df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
ax = df["itemDescription"].value_counts().plot(kind="bar",figsize=(40,20),title="Support")
ax.set_xlabel("Item")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df["single_transaction"] = df["Member_number"].astype(str)+"_"+df["Date"].astype(str)
df.head()
# Out:
#    Member_number        Date   itemDescription single_transaction
# 0           1808  21-07-2015    tropical fruit    1808_21-07-2015
# 1           2552  05-01-2015        whole milk    2552_05-01-2015
# 2           2300  19-09-2015         pip fruit    2300_19-09-2015
# 3           1187  12-12-2015  other vegetables    1187_12-12-2015
# 4           3037  01-02-2015        whole milk    3037_01-02-2015

# %%
df1 = pd.crosstab(df["single_transaction"],df["itemDescription"])
df1.head(5)
# Out:
# itemDescription     Instant food products  UHT-milk  ...  yogurt  zwieback
# single_transaction                                   ...
# 1000_15-03-2015                         0         0  ...       1         0
# 1000_24-06-2014                         0         0  ...       0         0
# 1000_24-07-2015                         0         0  ...       0         0
# 1000_25-11-2015                         0         0  ...       0         0
# 1000_27-05-2015                         0         0  ...       0         0
#
# [5 rows x 167 columns]

# %%
def encode(item_freq):
    res = 0
    if item_freq > 0:
        res = 1
    return res
basket_input = df1.applymap(encode)
basket_input
# Out:
# itemDescription     Instant food products  UHT-milk  ...  yogurt  zwieback
# single_transaction                                   ...
# 1000_15-03-2015                         0         0  ...       1         0
# 1000_24-06-2014                         0         0  ...       0         0
# 1000_24-07-2015                         0         0  ...       0         0
# 1000_25-11-2015                         0         0  ...       0         0
# 1000_27-05-2015                         0         0  ...       0         0
# ...                                   ...       ...  ...     ...       ...
# 4999_24-01-2015                         0         0  ...       1         0
# 4999_26-12-2015                         0         0  ...       0         0
# 5000_09-03-2014                         0         0  ...       0         0
# 5000_10-02-2015                         0         0  ...       0         0
# 5000_16-11-2014                         0         0  ...       0         0
#
# ...

# %%
frequent_itemsets = apriori(basket_input,min_support=0.001,use_colnames=True)
rules = association_rules(frequent_itemsets,metric="lift")
rules.head()
# Out:
#           antecedents         consequents  ...  leverage  conviction
# 0          (UHT-milk)     (bottled water)  ... -0.000228    0.988755
# 1     (bottled water)          (UHT-milk)  ... -0.000228    0.996168
# 2          (UHT-milk)  (other vegetables)  ... -0.000473    0.975443
# 3  (other vegetables)          (UHT-milk)  ... -0.000473    0.996060
# 4          (UHT-milk)           (sausage)  ... -0.000154    0.992371
#
# [5 rows x 9 columns]

# %%
rules.sort_values(["support","confidence","lift"],axis = 0,ascending=False).head(10)
# Out:
#             antecedents         consequents  ...  leverage  conviction
# 622        (rolls/buns)        (whole milk)  ... -0.003404    0.964550
# 623        (whole milk)        (rolls/buns)  ... -0.003404    0.976350
# 694            (yogurt)        (whole milk)  ... -0.002401    0.967861
# 695        (whole milk)            (yogurt)  ... -0.002401    0.983638
# 550              (soda)  (other vegetables)  ... -0.002166    0.975219
# 551  (other vegetables)              (soda)  ... -0.002166    0.980729
# 648           (sausage)        (whole milk)  ... -0.000575    0.988811
# 649        (whole milk)           (sausage)  ... -0.000575    0.996140
# 625            (yogurt)        (rolls/buns)  ... -0.001628    0.979147
# 624        (rolls/buns)            (yogurt)  ... -0.001628    0.984071
#
# [10 rows x 9 columns]

# %% [markdown]
# With this we can say that there is high probability that (rolls,milk), (milk,yogurt), (soda,vegetables) etc. can be sold together or they are antecedent or consequent of each other,So the retailer or company should sell these combination products together to increase their sales and generate more revenue.

# %%
file_name = "MBA_df.xlsx"
rules.to_excel(file_name)
print("DataFrame is written to excel file successfully")
# Out:
# DataFrame is written to excel file successfully
